# %%
import requests
import json
from bs4 import BeautifulSoup

# %%
url = "https://droppii.vn/shop/"
response = requests.get(url)

# %%
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup.title.text
    
links = soup.select('.product-col > .product-inner > .product-image > a ')
product_image = soup.select('.product-col > .product-inner > .product-image > a > .inner > img ')
product_label = soup.select('.product-col > .product-inner > .product-image > a > .labels > .onhot ')
product_titles = soup.select('.product-col > .product-inner > .product-content > a > h3 ')
product_rating = soup.select('.product-col > .product-inner > .product-content > .rating-wrap > .rating-content > .star-rating   ')
product_price = soup.select('.product-col > .product-inner > .product-content > .price > .woocommerce-Price-amount > bdi  ')

# for label in product_label:
#     print(label.text.strip())
# for link in links:
    # print(link['href'])
# for title_ in product_titles:
#     print(title_['title'])
# for image_ in product_image:
#     print(f'image_src: {image_['src']}' )
# for price_ in product_price:
#     print(f'price: {price_.text.strip()}')

# %%
# thực thi JSON

from platform import node


products = []
print(len(links))
for i in range (len(links)):
    try: 

        label = product_label[i].text.strip() if i < len(product_label) else None
        product = {
            'link' : links[i]['href'],
            'image_src' : product_image[i]['src'],
            'label' : label,
            'title' : product_titles[i].text.strip(),
            'price' : product_price[i].text.strip(),
        }
        products.append(product)
    except IndexError:
        pass
# chuyen ve dang json

products_json = json.dumps(products, ensure_ascii= False, indent= 3)

print(products_json)
# Out:
# 34
# [
#    {
#       "link": "https://droppii.vn/san-pham/thuc-pham-bao-ve-suc-khoe-cnd-ginseng-nhan-sam-hoat-huyet/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2024/04/NHAN-SAM-HOAT-HUYET-3-1.jpg?x99204",
#       "label": "Hot",
#       "title": "Thực phẩm bảo vệ sức khỏe CND Ginseng nhân sâm hoạt huyết (kèm túi)",
#       "price": "490,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/hop-qua-tet-2024-cnd-ginseng-suc-khoe-thinh-vuong-kem-tui/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2024/04/NHAN-SAM-HOAT-HUYET.jpg?x99204",
#       "label": "Hot",
#       "title": "Combo sức khỏe gia đình CND Ginseng (kèm túi)",
#       "price": "2,065,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/thuc-pham-bo-sung-cnd-ginseng-nhan-sam-tao-do-hoa-tan-kem-tui/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2023/12/COMBO-SUC-KHOE-GIA-DINH-1.jpg?x99204",
#       "label": "Hot",
#       "title": "Nhân sâm và táo đỏ hòa tan (kèm túi)",
#       "price": "290,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/nhan-sam-hoa-tan-cnd-ginseng-red-hop-07-goi/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2023/12/BANNER-COMBO-TET.jpg?x99204",
#       "label": "Hot",
#       "title": "Thực phẩm bảo vệ sức khỏe CND GINSENG Red Nhân sâm hòa tan (hộp 7 gói)",
#       "price": "210,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/thuc-pham-bo-sung-cnd-ginseng-nhan-sam-tao-do-hoa-tan/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2023/08/nhan-sam-va-tao-do-02-2.png?x99204",
#       "label": "Hot",
#       "title": "Nhân sâm và táo đỏ hòa tan",
#       "price": "280,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/ghe-massage-smart-vogue-prime-og-5569/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2023/08/nhan-sam-va-tao-do-02.png?x99204",
#       "label": "Hot",
#       "title": "Ghế massage Smart Vogue Prime (OG-5569)-Smart Vogue Prime – Espresso",
#       "price": "39,000,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/may-xay-thuc-pham-da-nang-ku-dkfc1212/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2023/07/04.png?x99204",
#       "label": "Hot",
#       "title": "Máy xay thực phẩm đa năng KU DKFC1212",
#       "price": "1,200,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/bo-cham-nhay-tang-chieu-cao-midu/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2023/07/sam-3.png?x99204",
#       "label": "Hot",
#       "title": "Bộ chạm nhảy tăng chiều cao Midu",
#       "price": "120,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/vien-uong-ho-tro-chong-oxy-hoa-khang-viem-dau-man-tinh-mpower-curcumin-plus/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2023/08/nhan-sam-va-tao-do-02-2.png?x99204",
#       "label": "Hot",
#       "title": "Viên uống hỗ trợ kháng viêm, giúp chống oxy hóa hiệu quả cao – Mpower Curcumin Plus [Nghệ]",
#       "price": "880,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/thuc-pham-phat-trien-chieu-cao-va-bo-sung-canxi-cho-moi-lua-tuoi-midu-menaq7-180/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2023/04/nhan-sam-va-tao-do-02-300x300.png?x99204",
#       "label": "Hot",
#       "title": "Thực phẩm bảo vệ sức khỏe: MiduMenaQ7 180mcg",
#       "price": "360,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/son-sap-cchoi-lady-leader-l06-hong-flamingo-freedom/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2023/01/03-Smart-Vogue-Prime-300x300.png?x99204",
#       "label": "Hot",
#       "title": "Son Sáp C’Choi – Lady Leader",
#       "price": "390,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/thuc-pham-bo-sung-nest-go/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2023/01/02-Smart-Vogue-Prime-300x300.png?x99204",
#       "label": "Hot",
#       "title": "Thực phẩm bổ sung Nest Go",
#       "price": "298,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/combo-2-chai-ngoc-linh-truong-sinh-gold/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2023/01/DKFC1212-300x300.jpg?x99204",
#       "label": null,
#       "title": "Combo 2 chai Ngọc Linh Trường Sinh (GOLD)",
#       "price": "3,490,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/thuc-pham-bo-sung-ngoc-linh-truong-sinh-gold-kem-tui/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2023/01/DKFC1212-2-300x300.jpg?x99204",
#       "label": null,
#       "title": "Thực phẩm bổ sung ngọc linh trường sinh GOLD (kèm túi)",
#       "price": "1,890,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/sam-ngoc-linh-truong-sinh-do-thung-24-lon/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2022/10/Ảnh-bìa-300x300.jpg?x99204",
#       "label": null,
#       "title": "Sâm Ngọc Linh Trường Sinh Đỏ (Thùng 24 lon)",
#       "price": "466,560 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/combo-6-dich-chiet-sam-ngoc-linh/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2022/10/Ảnh-chi-tiết-1-300x300.jpg?x99204",
#       "label": null,
#       "title": "Combo 6 dịch chiết Sâm Ngọc Linh",
#       "price": "1,620,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/combo-6-hop-da-day-truong-sinh/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2022/08/Ảnh-bìa-sản-phẩm-trực-diện-300x300.png?x99204",
#       "label": null,
#       "title": "Combo 6 hộp dạ dày Trường Sinh",
#       "price": "1,400,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/goi-nuoc-uong-qua-nhan-sam-ginseng-berry-s-drink-kem-tui/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2022/08/Ảnh-bìa-SP-từ-bên-trái-300x300.png?x99204",
#       "label": null,
#       "title": "Gói – Nước uống Quả nhân sâm Ginseng Berry S Drink (kèm túi)",
#       "price": "490,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/combo-4-bo-dau-goi-chong-rung-toc-kich-thich-moc-toc-elfa-pharm-goi-xa-serum/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2022/06/180.png-300x300.png?x99204",
#       "label": null,
#       "title": "Combo 4: Bộ dầu gội chống rụng tóc & kích thích mọc tóc Elfa pharm ( gội + xả + serum )",
#       "price": "800,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/combo-5-02-sua-tam-agrado-huong-vanilla-va-sua-tam-agrado-huong-gold/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2022/05/Hinh-1.jpg?x99204",
#       "label": null,
#       "title": "Combo 5: Sữa tắm Agrado Hương Vanilla và Sữa tắm Agrado Hương Gold",
#       "price": "468,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/thuc-pham-bo-sung-sua-hat-deltago/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2022/05/Hinh-2.jpg?x99204",
#       "label": null,
#       "title": "Thực Phẩm Bổ Sung Sữa Hạt DeltaGo",
#       "price": "485,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/may-suoi-s970/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2022/02/nest-go-hộp-510x382-1-300x300.png?x99204",
#       "label": null,
#       "title": "Máy sưởi S970",
#       "price": "2,150,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/may-suoi-s720s/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2024/11/3.jpg?x99204",
#       "label": null,
#       "title": "Máy sưởi S720S",
#       "price": "1,375,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/set-cao-rau-nam-cm24/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2024/11/2.png?x99204",
#       "label": null,
#       "title": "Set cạo râu nam CM24",
#       "price": "189,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/sua-tam-agrado/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2024/11/z5999655810738_3f55e702f464234dc17e77c05b45d25d.jpg?x99204",
#       "label": null,
#       "title": "Sữa tắm Agrado",
#       "price": "290,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/kem-duong-da-tay-huong-go-dan-huong-frudia-reproust-essential-blending-hand-cream-earthy-50g/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2024/11/4.png?x99204",
#       "label": null,
#       "title": "Kem dưỡng da tay hương Gỗ Đàn Hương Frudia Re:proust Essential Blending Hand Cream Earthy 50g",
#       "price": "198,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/sap-khu-mui-mine-perfumed-deodorant-stick-stay-sexy-50g/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2024/11/10.png?x99204",
#       "label": null,
#       "title": "Sáp khử mùi Mine perfumed deodorant stick stay Sexy 50g",
#       "price": "399,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/xit-rang-mieng-pharphap-dental-kids/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2024/11/2.jpg?x99204",
#       "label": null,
#       "title": "XỊT RĂNG MIỆNG  PHARPHAP DENTAL KIDS",
#       "price": "150,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/combo-xoa-nam-tan-nhang-nang-cao-newland-dr-lee/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2024/11/13.png?x99204",
#       "label": null,
#       "title": "Bộ chăm sóc da nám – tàn nhang nâng cao Newland & +Dr.lee",
#       "price": "3,044,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/acnaut-oxy-wash-cleasing-gel-50ml/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2024/11/14.png?x99204",
#       "label": null,
#       "title": "ACNAUT Oxy Wash Cleasing Gel 50ml",
#       "price": "170,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/acnaut-active-cream-15ml/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2024/10/z5865670563057_467d5f0097d7d18990f7f43c17643229.jpg?x99204",
#       "label": null,
#       "title": "ACNAUT Active cream 15ml",
#       "price": "399,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/dau-duong-co-the-thu-gian-relax-body-oil-100ml/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2024/10/z5865670383893_df7b8057a82f0bed6a68fbb923d44897.jpg?x99204",
#       "label": null,
#       "title": "DẦU DƯỠNG THỂ THƯ GIÃN BOTANY dầu jojoba/ kinh giới ngọt/ hoa oải hương",
#       "price": "395,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/sua-tam-tao-bot-spa-cao-cap-luxury-spa-bath-foam/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2024/10/97d7f09ed96d6033397c.jpg?x99204",
#       "label": null,
#       "title": "SỮA TẮM TẠO BỌT VÀ SPA CAO CẤP BOTANY chi nhài,gỗ sắc hồng,hoa phong lữ (chai 500ml)",
#       "price": "445,000 ₫"
#    },
#    {
#       "link": "https://droppii.vn/san-pham/sua-duong-the-hand-body-lotion-nourish/",
#       "image_src": "https://droppii.vn/wp-content/uploads/2024/10/bafd09ba20499917c058.jpg?x99204",
#       "label": null,
#       "title": "SỮA DƯỠNG TOÀN THÂN VÀ DA TAY BOTANY tinh dầu vỏ cam quýt, chanh sim, cam Bergamot (chai 500ml)",
#       "price": "495,000 ₫"
#    }
# ]
